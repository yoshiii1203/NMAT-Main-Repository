# %%
# ============================================================
#  Install dependencies all dependencies for running the notebooks and streamlit app
# ============================================================
# !pip -q install -U pandas numpy pyarrow matplotlib seaborn scipy scikit-posthocs plotly kaleido rapidfuzz unidecode tqdm streamlit
